# %% [markdown]
# # Car Price Prediction Project

# %% [markdown]
# >With the covid 19 impact in the market, we have seen lot of changes in the car market. Now some cars are in
# demand hence making them costly and some are not in demand hence cheaper. One of our clients works with
# small traders, who sell used cars. With the change in market due to covid 19 impact, our client is facing problems
# with their previous car price valuation machine learning models. So, they are looking for new machine learning
# models from new data. We have to make carprice valuation model.

# %% [markdown]
# #### Importing the required libraries.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import pandas as pd
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('used_cars.csv') #importing the collected data

# %%
df
# Out:
#        LOCATION  MNF_YEAR    BRAND                       MODEL    VARIANT  \
# 0     New Delhi      2018     Ford   Ecosport 1.5TITANIUM TDCI     Manual
# 1     New Delhi      2019  Hyundai  VENUE 1.0 TURBO GDI SX+ AT  Automatic
# 2     New Delhi      2018   Maruti           Vitara Brezza VDI     Manual
# 3     New Delhi      2018   Maruti           Vitara Brezza VDI     Manual
# 4     New Delhi      2018  Hyundai          Creta 1.6 E + VTVT     Manual
# ...         ...       ...      ...                         ...        ...
# 1216  Ahmedabad      2019   Maruti     Ertiga ZXI SMART HYBRID     Manual
# 1217  Ahmedabad      2016  Hyundai    Creta 1.6 S PLUS AT CRDI     Manual
# 1218  Ahmedabad      2013   Toyota   Innova 2.5 VX 8 STR BS IV     Manual
# 1219  Ahmedabad      2020  Hyundai        VENUE S MT 1.2 KAPPA     Manual
# 1220  Ahmedabad      2018  Hyundai      Creta 1.6 SX AT PETROL  Automatic
#
#         DRIVEN_KM FUELTYPE NOOF_OWNERS       PRICE
# 0       21,169 km   Diesel   1st Owner   ₹8,88,999
# 1        7,676 km   Petrol   1st Owner   ₹9,95,499
# 2       40,458 km   Diesel   1st Owner   ₹7,79,299
# 3       82,601 km   Diesel   1st Owner   ₹6,36,299
# 4       39,294 km   Petrol   2nd Owner   ₹8,98,799
# ...           ...      ...         ...         ...
# 1216     8,424 km   Petrol   1st Owner   ₹9,44,399
# 1217    94,709 km   Diesel   1st Owner   ₹7,76,099
# 1218  2,80,921 km   Diesel   2nd Owner   ₹7,05,599
# 1219     4,689 km   Petrol   1st Owner   ₹7,75,399
# 1220    27,656 km   Petrol   1st Owner  ₹12,46,599
#
# [1221 rows x 9 columns]

# %% [markdown]
# # EDA.
# Starting the EDA with general play around with the data.

# %%
df.columns
# Out:
# Index(['LOCATION', 'MNF_YEAR', 'BRAND', 'MODEL', 'VARIANT', 'DRIVEN_KM',
#        'FUELTYPE', 'NOOF_OWNERS', 'PRICE'],
#       dtype='object')

# %%
df.LOCATION.unique()
# Out:
# array(['New Delhi', 'Noida', 'Gurgaon', 'Mumbai', 'Pune', 'Bengaluru',
#        'Hyderabad', 'Chennai', 'Kolkata', 'Ahmedabad'], dtype=object)

# %%
df.MNF_YEAR.unique()
# Out:
# array([2018, 2019, 2017, 2016, 2015, 2014, 2020, 2013, 2012, 2011, 2010,
#        2021, 2009], dtype=int64)

# %%
df.BRAND.unique()
# Out:
# array(['Ford', 'Hyundai', 'Maruti', 'Toyota', 'Mahindra', 'Volkswagen',
#        'Skoda', 'Honda', 'BMW', 'Mercedes', 'Ssangyong', 'Audi', 'Tata',
#        'Renault', 'Datsun', 'Nissan', 'Jeep'], dtype=object)

# %%
df.VARIANT.unique()
# Out:
# array(['Manual', 'Automatic', nan], dtype=object)

# %%
df.NOOF_OWNERS.unique()
# Out:
# array(['1st Owner', '2nd Owner', '3rd Owner'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# 338

# %%
df.isnull().sum()
# Out:
# LOCATION        0
# MNF_YEAR        0
# BRAND           0
# MODEL           0
# VARIANT        11
# DRIVEN_KM       0
# FUELTYPE        0
# NOOF_OWNERS     0
# PRICE           0
# dtype: int64

# %% [markdown]
# ### Cleaning the Data.

# %% [markdown]
# #### Removing the Duplicate Records.

# %%
df = df.drop_duplicates() #Because we have too many duplicate records we will detete them to have a good model

# %%
df.isnull().sum()
# Out:
# LOCATION        0
# MNF_YEAR        0
# BRAND           0
# MODEL           0
# VARIANT        10
# DRIVEN_KM       0
# FUELTYPE        0
# NOOF_OWNERS     0
# PRICE           0
# dtype: int64

# %% [markdown]
# From above we can see that the only in VARIANT we have values missing so we will change VARIANT nan values as NOT MENTIONED

# %% [markdown]
# ### Mathematical/ Analytical Modeling of the Data

# %%
df['VARIANT'] = df['VARIANT'].fillna('NOT MENTIONED')

# %%
DF = df.copy()

# %%
from sklearn.preprocessing import LabelEncoder
LE= LabelEncoder()
catagorical_data = ['LOCATION' , 'MNF_YEAR', 'BRAND', 'MODEL', 'VARIANT', 'FUELTYPE' , 'NOOF_OWNERS' ]

for i in catagorical_data:
    DF[i]=DF[i].astype('str')
    DF[i]=LE.fit_transform(DF[i])

# %%
DF['PRICE'] = DF['PRICE'].str.replace(r'\D', '').astype(int)
DF['DRIVEN_KM'] = DF['DRIVEN_KM'].str.replace(r'\D', '').astype(int)

# %%
DF.describe()
# Out:
#          LOCATION    MNF_YEAR       BRAND       MODEL     VARIANT  \
# count  883.000000  883.000000  883.000000  883.000000  883.000000
# mean     5.440544    7.619479    7.231031  136.996602    0.857305
# std      2.939995    2.135475    3.019752   84.532521    0.380983
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    6.000000    5.000000   60.500000    1.000000
# 50%      6.000000    8.000000    8.000000  136.000000    1.000000
# 75%      8.000000    9.000000    8.000000  216.000000    1.000000
# max      9.000000   12.000000   16.000000  279.000000    2.000000
#
#            DRIVEN_KM    FUELTYPE  NOOF_OWNERS         PRICE
# count     883.000000  883.000000   883.000000  8.830000e+02
# mean    43526.952435    0.703284     0.219706  6.267737e+05
# std     33833.245517    0.485925     0.453479  2.953709e+05
# min       470.000000    0.000000     0.000000  1.632990e+05
# 25%     18909.500000    0.000000     0.000000  4.264990e+05
# 50%     34119.000000    1.000000     0.000000  5.699990e+05
# 75%     62205.000000    1.000000     0.000000  7.309490e+05
# max    280921.000000    2.000000     2.000000  2.322099e+06

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 883 entries, 0 to 1184
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LOCATION     883 non-null    int32
#  1   MNF_YEAR     883 non-null    int32
#  2   BRAND        883 non-null    int32
#  3   MODEL        883 non-null    int32
#  4   VARIANT      883 non-null    int32
#  5   DRIVEN_KM    883 non-null    int32
#  6   FUELTYPE     883 non-null    int32
#  7   NOOF_OWNERS  883 non-null    int32
#  8   PRICE        883 non-null    int32
# dtypes: int32(9)
# memory usage: 37.9 KB

# %% [markdown]
# ### Correlation of the Data

# %%
plt.figure(figsize=(30,20))
sns.heatmap(DF.corr(), annot = True, cmap= "coolwarm")
plt.show()

# %%
plt.figure(figsize=(15,7))
DF.corr()["PRICE"].sort_values(ascending=False).drop(["PRICE"]).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of Fetures with the target column", fontsize=25)
plt.show()
cor=pd.DataFrame(DF.corr()["PRICE"].sort_values(ascending=False)).drop(["PRICE"])
print("KEY OBSERVATIONS:\n ")
cor
# Out:
# KEY OBSERVATIONS:
#                 PRICE
# MNF_YEAR     0.375904
# NOOF_OWNERS  0.035179
# MODEL        0.005355
# BRAND       -0.040116
# DRIVEN_KM   -0.055501
# LOCATION    -0.077938
# FUELTYPE    -0.245683
# VARIANT     -0.312011

# %% [markdown]
# ### Key Observations:
#    1. From above we can clearly see that MNF_YEAR is postivly correlated to PRICE and FUEL_TYPE and VARIENT is negative corelated to PRICE

# %%
DF.PRICE.hist(bins =10,figsize=(20,5), color ="pink")
plt.axvline(np.mean(DF.PRICE), linewidth = 5, color = "red", label = "mean PRICE")
plt.xlabel("PRIZE")
plt.ylabel("count")
plt.legend()
plt.show()
print("MATHEMATICAL SUMMARY OF PRIZE :\n",\
      DF.PRICE.describe())
# Out:
# MATHEMATICAL SUMMARY OF PRIZE :
#  count    8.830000e+02
# mean     6.267737e+05
# std      2.953709e+05
# min      1.632990e+05
# 25%      4.264990e+05
# 50%      5.699990e+05
# 75%      7.309490e+05
# max      2.322099e+06
# Name: PRICE, dtype: float64

# %% [markdown]
# ### Key observations:
# 1. Mean of the prize is Rs: 5,33,047, the prize is distributed between Rs: 99,162 to Rs: 41,00,000.
# 2. Above we can understand that most of the Car price is leser than the Mean i.e Rs: 5,33,047.

# %%
DF.DRIVEN_KM.hist(bins =10,figsize=(20,5), color ="pink")
plt.axvline(np.mean(DF.DRIVEN_KM), linewidth = 5, color = "red", label = "mean DRIVEN_KM")
plt.xlabel("DRIVEN_KM")
plt.ylabel("count")
plt.legend()
plt.show()
print("MATHEMATICAL SUMMARY OF PRIZE :\n",\
      DF.DRIVEN_KM.describe())
# Out:
# MATHEMATICAL SUMMARY OF PRIZE :
#  count       883.000000
# mean      43526.952435
# std       33833.245517
# min         470.000000
# 25%       18909.500000
# 50%       34119.000000
# 75%       62205.000000
# max      280921.000000
# Name: DRIVEN_KM, dtype: float64

# %% [markdown]
# ### Key observations:
# 1. Mean of the DRIVEN_KM is 64489.278888kms and the maximum KMS driven is  312882kms.
# 2. Above we can understand that most of the Car comes to sellimg arround low kilometers driven.

# %% [markdown]
# ### Multivariate Analysis:

# %%
DF1 = df.copy()

# %%
DF1['PRICE'] = DF1['PRICE'].str.replace(r'\D', '').astype(int)
DF1['DRIVEN_KM'] = DF1['DRIVEN_KM'].str.replace(r'\D', '').astype(int)

# %%
plt.figure(figsize=(20,5))
mean_cost = np.mean(DF.PRICE)
sns.boxplot(x = "LOCATION",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.title("LOCATION Vs PRICE", fontsize = 30)
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(20,5))
sns.barplot(x = "LOCATION",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Key observations:
# 1. New Delhi, Noida, Gurgaon have the costiliest cars and Mumbai, Pune, Ahmedabad have most cars being sold.
# 2. We have Bengaluru, Hyderabad, Chennai, Kolkata have least cars being sold and also comprativly cheaper.

# %%
plt.figure(figsize=(20,5))
mean_cost = np.mean(DF.PRICE)
sns.boxplot(x = "MNF_YEAR",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.title("MNF_YEAR Vs PRICE", fontsize = 30)
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(20,5))
sns.barplot(x = "MNF_YEAR",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Key observations:
# 1. 2019, 2020, 2021 model are being sold higher in PRICE and also above average PRICE.
# 2. Above we can understand thatcars sold in lesser kms driven and also in lesser years used are sold in high price.

# %%
plt.figure(figsize=(20,5))
mean_cost = np.mean(DF.PRICE)
sns.boxplot(x = "BRAND",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.title("BRAND Vs PRICE", fontsize = 30)
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(20,5))
sns.barplot(x = "BRAND",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Key observations:
# 1. When comes to the Brand Land rover are being the costliest in country followed by Jaguar
# 2. And most of the other brands including most of the foreign brands are below the PRICE mean line

# %%
plt.figure(figsize=(20,5))
mean_cost = np.mean(DF.PRICE)
sns.boxplot(x = "VARIANT",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.title("VARIANT Vs PRICE", fontsize = 30)
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(20,5))
sns.barplot(x = "VARIANT",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Key observations:
# 1. We can see that the automatic engines are costliest in the market. And also most costilier cars comes in Automatic Drift.

# %%
plt.figure(figsize=(20,5))
mean_cost = np.mean(DF.PRICE)
sns.boxplot(x = "FUELTYPE",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.title("FUELTYPE Vs PRICE", fontsize = 30)
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(20,5))
sns.barplot(x = "FUELTYPE",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Key observations:
# 1. Diesel being the chepeast and most efficient fuel type, and so the Desiel engines are being the costiliest fuel types.
# 2. Petrol bend second prefered followed by CNG and LPG fuel types.

# %%
plt.figure(figsize=(20,5))
mean_cost = np.mean(DF.PRICE)
sns.boxplot(x = "NOOF_OWNERS",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.title("NOOF_OWNERS Vs PRICE", fontsize = 30)
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(20,5))
sns.barplot(x = "NOOF_OWNERS",y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Key observation:
# 1. 1st owner cars are costilest followed by second and third.

# %%
plt.figure(figsize=(20,5))
mean_cost = np.mean(DF.PRICE)
sns.scatterplot(x = 'DRIVEN_KM',y = "PRICE", data = DF1, palette = "rainbow")
plt.axhline(mean_cost, color = "b", linestyle="dashed", linewidth=2)
plt.title("DRIVEN_KM Vs PRICE", fontsize = 30)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Key Observations:
# 1. The lesser kms driven are evidently sold costilier.

# %% [markdown]
# ## Data Pre-Processing.

# %% [markdown]
# ### Lets observe the skewness and outliers in the Data.

# %%
plt.figure(figsize=(15,15))
for i in range (0, len(DF.columns)):
    plt.subplot(6,4,i+1)         
    sns.kdeplot(DF[DF.columns[i]], color = "purple")
    plt.title(f"Skewness = {round(DF[DF.columns[i]].skew(),5)}",fontsize=15)
    plt.tight_layout()

# %% [markdown]
# Lets also see the Outliers mathematically.

# %%
from scipy.stats import zscore

z= np.abs(zscore(DF))
threshold= 3
df_new = DF[(z < 3).all(axis=1)]

# %%
print(f"Orginal Data {DF.shape}\nAfter Removing outliers {df_new.shape}\nThe percentage of data loss {((8308-7765)/8308)*100}%")
# Out:
# Orginal Data (883, 9)
# After Removing outliers (823, 9)
# The percentage of data loss 6.535869041887338%

# %% [markdown]
# We have many outliers and we also have skewness in the data. Because its more, correcting them will have loss in the data orr data will be deformed. So we are deciding to work with the same.

# %%
x_1=DF.drop(["PRICE"], axis = 1)
y_1=DF.PRICE

# %%
x_1
# Out:
#       LOCATION  MNF_YEAR  BRAND  MODEL  VARIANT  DRIVEN_KM  FUELTYPE  \
# 0            7         9      3    107        1      21169         0
# 1            7        10      5    228        0       7676         1
# 2            7         9      8    241        1      40458         0
# 3            7         9      8    241        1      82601         0
# 4            7         9      5     78        1      39294         1
# ...        ...       ...    ...    ...      ...        ...       ...
# 1180         0        11      8     10        1      11061         1
# 1181         0         9      0      1        0      39254         0
# 1182         0         9      6     70        1      57010         0
# 1183         0         3     15    138        1     184782         0
# 1184         0        10      6     69        1      60802         0
#
#       NOOF_OWNERS
# 0               0
# 1               0
# 2               0
# 3               0
# 4               1
# ...           ...
# 1180            0
# 1181            1
# 1182            0
# 1183            2
# 1184            0
#
# [883 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_1 = sc.fit_transform(x_1)

# %% [markdown]
# ###  Model Building

# %% [markdown]
# ### Selecting parameters for training

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, cross_val_predict, cross_validate
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error

accu = 0
for i in range(0,1000):
    x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x_1,y_1,test_size = .25, random_state = i)
    mod = LinearRegression()
    mod.fit(x_train_1,y_train_1)
    y_pred_1 = mod.predict(x_test_1)
    tempacc = r2_score(y_test_1,y_pred_1)
    if tempacc> accu:
        accu= tempacc
        best_rstate=i

print(f"Best Accuracy {accu*100} found on randomstate {best_rstate}")
# Out:
# Best Accuracy 46.22071850505682 found on randomstate 451

# %%
x_train, x_test, y_train, y_test = train_test_split(x_1,y_1,test_size = .25, random_state = best_rstate)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor

# %% [markdown]
# ### Shortlisting the best model

# %%
models = [LinearRegression(), Lasso(), Ridge(alpha=1, random_state=42), ElasticNet(), SVR(), KNeighborsRegressor(), DecisionTreeRegressor(), AdaBoostRegressor(random_state=42), RandomForestRegressor(random_state=42)]

model_names = ["LinearRegression", "Lasso", "Ridge", "ElasticNet", "SVR", "KNeighborsRegressor", "DecisionTreeRegressor", "AdaBoostRegressor", "RandomForestRegressor"]

# %%
score= []
mean_abs_e=[]
mean_sqr_e=[]
root_mean_e=[]
r2=[]

for m in models:
    m.fit(x_train,y_train)
    print("Score of", m, "is:", m.score(x_train,y_train))
    score.append(m.score(x_train,y_train))
    predm=m.predict(x_test)
    print("\nERROR:")
    print("MEAN ABSOLUTE ERROR: ",mean_absolute_error(y_test,predm))
    mean_abs_e.append(mean_absolute_error(y_test,predm))
    print("MEAN SQUARED ERROR: ", mean_squared_error(y_test,predm))
    mean_sqr_e.append(mean_squared_error(y_test,predm))
    print("ROOT MEAN SQUARED ERROR :",np.sqrt(mean_squared_error(y_test,predm)))
    root_mean_e.append(np.sqrt(mean_squared_error(y_test,predm)))
    print("R2 SCORE: ", r2_score(y_test,predm))
    r2.append(r2_score(y_test,predm))
    print("**********************************************************************************************************")
    print('\n\n')
# Out:
# Score of LinearRegression() is: 0.2764418828520785
#
# ERROR:
# MEAN ABSOLUTE ERROR:  153317.62113464746
# MEAN SQUARED ERROR:  42288933519.83974
# ROOT MEAN SQUARED ERROR : 205642.73271827464
# R2 SCORE:  0.46220718505056824
# **********************************************************************************************************
#
#
#
# Score of Lasso() is: 0.2764418827391534
#
# ERROR:
# MEAN ABSOLUTE ERROR:  153317.12035566574
# MEAN SQUARED ERROR:  42288916035.163025
# ROOT MEAN SQUARED ERROR : 205642.6902060052
# R2 SCORE:  0.46220740740504074
# **********************************************************************************************************
#
#
#
# Score of Ridge(alpha=1, random_state=42) is: 0.27644098557138996
#
# ERROR:
# MEAN ABSOLUTE ERROR:  153270.27351817428
# MEAN SQUARED ERROR:  42294751087.211716
# ROOT MEAN SQUARED ERROR : 205656.87707249596
# R2 SCORE:  0.46213320243448586
# **********************************************************************************************************
#
#
#
# Score of ElasticNet() is: 0.23919736124706326
#
# ERROR:
# MEAN ABSOLUTE ERROR:  156908.32951991397
# MEAN SQUARED ERROR:  48071437745.625496
# ROOT MEAN SQUARED ERROR : 219251.99599006047
# R2 SCORE:  0.3886704706857248
# **********************************************************************************************************
#
#
#
# Score of SVR() is: -0.03870448191319009
#
# ERROR:
# MEAN ABSOLUTE ERROR:  203659.1166823824
# MEAN SQUARED ERROR:  81536801090.59796
# ROOT MEAN SQUARED ERROR : 285546.4954969645
# R2 SCORE:  -0.03691207440623945
# **********************************************************************************************************
#
#
#
# Score of KNeighborsRegressor() is: 0.6013922951773296
#
# ERROR:
# MEAN ABSOLUTE ERROR:  144375.38280542986
# MEAN SQUARED ERROR:  44434586811.117096
# ROOT MEAN SQUARED ERROR : 210795.12995113785
# R2 SCORE:  0.4349206864946231
# **********************************************************************************************************
#
#
#
# Score of DecisionTreeRegressor() is: 1.0
#
# ERROR:
# MEAN ABSOLUTE ERROR:  62931.21266968326
# MEAN SQUARED ERROR:  20054055485.9819
# ROOT MEAN SQUARED ERROR : 141612.34227983767
# R2 SCORE:  0.7449704673706519
# **********************************************************************************************************
#
#
#
# Score of AdaBoostRegressor(random_state=42) is: 0.6073790098597034
#
# ERROR:
# MEAN ABSOLUTE ERROR:  152785.66308670962
# MEAN SQUARED ERROR:  37908382071.2866
# ROOT MEAN SQUARED ERROR : 194700.7500532204
# R2 SCORE:  0.5179151185089274
# **********************************************************************************************************
#
#
#
# Score of RandomForestRegressor(random_state=42) is: 0.9757568626733671
#
# ERROR:
# MEAN ABSOLUTE ERROR:  65272.11031674207
# MEAN SQUARED ERROR:  12155931040.30154
# ROOT MEAN SQUARED ERROR : 110253.93888792155
# R2 SCORE:  0.8454117465641939
# **********************************************************************************************************

# %%
mean_score=[]
STD=[]
for m in models:
    CV=cross_val_score(m,x_1,y_1,cv=5,scoring="r2")
    print("SCORE OF",m,"IS as follows...")
    print("SCORE IS:", CV)
    print("MEAN OF SCORE is :", CV.mean())
    mean_score.append(CV.mean())
    print("Standard Deviation :", CV.std())
    STD.append(CV.std())
    print("**************************************************************************************************")
    print("\n\n")
# Out:
# SCORE OF LinearRegression() IS as follows...
# SCORE IS: [0.22966617 0.29020904 0.36038133 0.15098832 0.31944156]
# MEAN OF SCORE is : 0.2701372854894236
# Standard Deviation : 0.07322862893163418
# **************************************************************************************************
#
#
#
# SCORE OF Lasso() IS as follows...
# SCORE IS: [0.22966621 0.2902078  0.36038348 0.15099209 0.31944467]
# MEAN OF SCORE is : 0.27013885191967163
# Standard Deviation : 0.0732282830950267
# **************************************************************************************************
#
#
#
# SCORE OF Ridge(alpha=1, random_state=42) IS as follows...
# SCORE IS: [0.22961398 0.29015634 0.36044305 0.15131531 0.3196613 ]
# MEAN OF SCORE is : 0.2702379973124594
# Standard Deviation : 0.07317003792543933
# **************************************************************************************************
#
#
#
# SCORE OF ElasticNet() IS as follows...
# SCORE IS: [0.18727099 0.24292222 0.32265951 0.17627735 0.30313585]
# MEAN OF SCORE is : 0.24645318206126482
# Standard Deviation : 0.05909310626433935
# **************************************************************************************************
#
#
#
# SCORE OF SVR() IS as follows...
# SCORE IS: [-0.14368044 -0.00181144 -0.00235928 -0.14490919 -0.01936891]
# MEAN OF SCORE is : -0.06242585095026949
# Standard Deviation : 0.06714433426774766
# **************************************************************************************************
#
#
#
# SCORE OF KNeighborsRegressor() IS as follows...
# SCORE IS: [0.31383361 0.5014349  0.48150815 0.14133483 0.40865935]
# MEAN OF SCORE is : 0.36935416764950196
# Standard Deviation : 0.13163896184415094
# **************************************************************************************************
#
#
#
# SCORE OF DecisionTreeRegressor() IS as follows...
# SCORE IS: [0.74857955 0.96829458 0.94933819 0.54852678 0.17852871]
# MEAN OF SCORE is : 0.6786535611195275
# Standard Deviation : 0.29295377778312004
# **************************************************************************************************
#
#
#
# SCORE OF AdaBoostRegressor(random_state=42) IS as follows...
# SCORE IS: [0.68898393 0.5009417  0.38182633 0.54406278 0.34810358]
# MEAN OF SCORE is : 0.4927836676258207
# Standard Deviation : 0.12201188645877445
# **************************************************************************************************
#
#
#
# SCORE OF RandomForestRegressor(random_state=42) IS as follows...
# SCORE IS: [0.75349933 0.94289861 0.89009354 0.67390508 0.53572401]
# MEAN OF SCORE is : 0.7592241130623926
# Standard Deviation : 0.1470561375230803
# **************************************************************************************************

# %%
Regression_result = pd.DataFrame({"MODEL": model_names,
                                  "SCORE": score,
                                  "CV_mean_score": mean_score,
                                  "CV_STD": STD,
                                  "MBE": mean_abs_e,
                                  "MSE": mean_sqr_e,
                                  "RMSE": root_mean_e,
                                  "R2":r2 
                                 })
Regression_result.sort_values(by="CV_mean_score", ascending=False)
# Out:
#                    MODEL     SCORE  CV_mean_score    CV_STD            MBE  \
# 8  RandomForestRegressor  0.975757       0.759224  0.147056   65272.110317
# 6  DecisionTreeRegressor  1.000000       0.678654  0.292954   62931.212670
# 7      AdaBoostRegressor  0.607379       0.492784  0.122012  152785.663087
# 5    KNeighborsRegressor  0.601392       0.369354  0.131639  144375.382805
# 2                  Ridge  0.276441       0.270238  0.073170  153270.273518
# 1                  Lasso  0.276442       0.270139  0.073228  153317.120356
# 0       LinearRegression  0.276442       0.270137  0.073229  153317.621135
# 3             ElasticNet  0.239197       0.246453  0.059093  156908.329520
# 4                    SVR -0.038704      -0.062426  0.067144  203659.116682
#
#             MSE           RMSE        R2
# 8  1.215593e+10  110253.938888  0.845412
# 6  2.005406e+10  141612.342280  0.744970
# 7  3.790838e+10  194700.750053  0.517915
# 5  4.443459e+10  210795.129951  0.434921
# 2  4.229475e+10  205656.877072  0.462133
# 1  4.228892e+10  205642.690206  0.462207
# 0  4.228893e+10  205642.732718  0.462207
# 3  4.807144e+10  219251.995990  0.388670
# 4  8.153680e+10  285546.495497 -0.036912

# %%
metrics_list = ["SCORE", "CV_mean_score", "CV_STD", "MBE", "MSE", "RMSE", "R2"]

for metric in metrics_list:
    Regression_result.sort_values(by=metric).plot.bar("MODEL", metric, color = "orange")
    plt.title(f"MODEL by {metric}")
    plt.show()

# %% [markdown]
# From above observation, we can come to a conclusion that Randomforest is the best model with Score of 98.78 lets try in Hyper tuning the same for improved performance and also to reduce the over fitting the Data.

# %%
rf = RandomForestRegressor(random_state=42)
cross_val_predict(rf, x_train, y_train, cv=5, n_jobs=-1).mean()
# Out:
# 629640.7289728097

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
predm=rf.predict(x_test)

# %%
predm
# Out:
# array([ 704423.  ,  870120.  ,  565721.  ,  622783.  ,  288241.  ,
#         434915.  ,  461907.  ,  754584.  ,  798160.02,  253101.  ,
#         575981.  ,  815963.  ,  420448.  ,  776980.  , 1083840.  ,
#         863466.  ,  540624.  ,  541827.  ,  527533.  ,  499096.  ,
#         482359.  ,  364898.  ,  313291.  ,  338927.  ,  520137.  ,
#         569756.  ,  487946.  ,  494159.  ,  510609.  ,  389678.  ,
#         464876.  ,  315399.  , 1459817.01,  457192.  ,  561280.  ,
#         426299.  ,  686991.  ,  604631.  ,  657508.  ,  773034.  ,
#         725936.  ,  433534.  ,  473597.  ,  692931.  ,  539863.  ,
#         482336.  , 1404735.  ,  564915.  , 1068781.  ,  803490.  ,
#         908883.  ,  354830.  ,  799551.  ,  732238.  , 1222839.  ,
#         419314.  ,  620899.  , 1401273.01,  480374.  ,  498200.  ,
#         594854.  ,  791655.03,  419581.  ,  700942.  ,  376280.  ,
#         884641.  ,  935479.  ,  693424.  ,  660199.  ,  699775.  ,
#         676931.  ,  575471.  ,  633975.  ,  462555.  ,  814599.  ,
#         834305.  ,  876531.  ,  720091.  ,  979315.  ,  705882.08,
#         455217.  ,  454062.  ,  797538.  ,  594669.  , 1051907.  ,
#        1143180.  ,  669796.  ,  664693.  ,  408033.  ,  690755.  ,
#         572224.  ,  668899.  ,  261796.  ,  709163.  ,  597995.  ,
#         566632.04,  629515.  ,  767858.  ,  657987.  ,  396783.  ,
#         635405.  ,  708582.  ,  767368.  , 1125775.  ,  411081.  ,
#         669497.  ,  689333.  ,  547437.  ,  434476.  ,  654393.  ,
#         344766.  ,  443520.  ,  390114.  , 1173997.  ,  729519.  ,
#         485805.  ,  868591.  ,  588672.  ,  459189.  , 1420593.  ,
#         426566.  ,  447277.  ,  448610.  ,  920394.  ,  544228.  ,
#         423323.  ,  441082.  ,  696624.  ,  765817.  ,  305005.  ,
#         773191.  ,  651114.  ,  604614.  ,  560849.  ,  259933.  ,
#         490842.  ,  391314.  ,  427677.  ,  318123.  ,  489434.  ,
#         966451.  ,  565505.  ,  464041.  ,  573568.  ,  768091.  ,
#         604856.  ,  661258.  ,  561785.19,  469243.  ,  512561.01,
#         273740.  ,  441996.  ,  836356.  ,  752891.  ,  401835.  ,
#         463101.  ,  634925.  ,  315173.  ,  246938.  ,  522340.  ,
#         426873.  ,  487374.  ,  616223.  ,  455923.  ,  495232.  ,
#         871931.  ,  929790.  ,  484255.  ,  720572.  ,  712249.04,
#         767946.  ,  434509.  ,  488704.  ,  895827.  ,  763551.  ,
#         665238.  , 1504474.  ,  490406.  , 1164278.  ,  446579.  ,
#         404204.  ,  599051.  ,  666054.  ,  513350.  ,  702058.01,
#         245863.  ,  380326.  ,  607308.  ,  676441.  ,  663413.  ,
#         753955.  ,  786875.  ,  368738.  ,  673015.  ,  972078.  ,
#         551574.26, 1094984.  ,  742564.01,  464462.  ,  558098.  ,
#         585472.  ,  765086.  ,  517481.  ,  626606.  ,  472148.  ,
#         683268.  ,  447709.  ,  413322.  ,  452254.  ,  402949.  ,
#         683463.  ,  548660.04,  803848.  ,  695602.  ,  517765.  ,
#         498380.  ,  549019.29,  672449.  ,  860008.  ,  296127.  ,
#         524501.  ])

# %%
rf.score(x_test,y_test), rf.score(x_train,y_train)
# Out:
# (0.8454117465641939, 0.9757568626733671)

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# ### Hyper Parameter Tuning.

# %%
param_grid = [
    {"bootstrap": [True, False],
     "criterion": ["mse", "mae"],
     "n_estimators"      : [10,20,30,50,100],
     "max_features"      : ["auto", "sqrt", "log2"],
     "min_samples_split" : [2,4,8],
    }
]

rf = RandomForestRegressor(random_state=42)

grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid=[{'bootstrap': [True, False],
#                           'criterion': ['mse', 'mae'],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'min_samples_split': [2, 4, 8],
#                           'n_estimators': [10, 20, 30, 50, 100]}],
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=False, criterion='mse', max_features='log2',
#                       n_estimators=50, random_state=42)

# %%
reg_final_model = grid_search.best_estimator_

# %%
reg_final_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=False, criterion='mse', max_features='log2',
#                       n_estimators=50, random_state=42)

# %%
grid_search.best_score_
# Out:
# 0.7978799051834334

# %%
reg_final_model.score(x_train_1,y_train_1), reg_final_model.score(x_test_1,y_test_1)
# Out:
# (0.9658829927118935, 0.9815609335196317)

# %% [markdown]
# #### Saving the final model

# %%
import joblib
joblib.dump(reg_final_model,"CARPRICE_PRED.obj")
# Out:
# ['CARPRICE_PRED.obj']

# %% [markdown]
# ### Summary and Conclusion :

# %% [markdown]
# > We have Hyper parameter tuned the model and improved the model score upto 99% with the Grid search cv score of 88.70%
#
# 1. The above model will help our seller to predict the Price of the user cars, and also will helps him to understand based on what factors the the Car Price is decided.
